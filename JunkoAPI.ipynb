# %%
# !git clone https://github.com/RosalinaSpeedy/junkoApi
# Out:
# Cloning into 'junkoApi'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 53 (delta 16), reused 49 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (53/53), 6.51 KiB | 6.51 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
import os
os.chdir("junkoApi")

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 102.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# !ngrok -v
# Out:
# ngrok version 3.22.1
# pyngrok version 7.2.8

# %%
# !ngrok authtoken 2vompsZ2IA7jKGlK1qtZ9qkszcc_7PLsSzxGRbmzAjey6iYo6
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !ngrok update
# Out:
# INFO[05-15|11:02:03] no configuration paths supplied
# DBUG[05-15|11:02:03] ngrok config file at legacy location does not exist legacy_path=/root/.config/ngrok/ngrok.yml
# INFO[05-15|11:02:03] using configuration at default config path path=/root/.config/ngrok/ngrok.yml
# INFO[05-15|11:02:03] open config file                         path=/root/.config/ngrok/ngrok.yml err=nil
# No update available, this is the latest version.

# %%
from pyngrok import conf
conf.get_default().config_path = "~/.config/ngrok/ngrok.yml"

# %%
# !ngrok update
# Out:
# INFO[05-15|11:02:08] no configuration paths supplied
# DBUG[05-15|11:02:08] ngrok config file at legacy location does not exist legacy_path=/root/.config/ngrok/ngrok.yml
# INFO[05-15|11:02:08] using configuration at default config path path=/root/.config/ngrok/ngrok.yml
# INFO[05-15|11:02:08] open config file                         path=/root/.config/ngrok/ngrok.yml err=nil
# No update available, this is the latest version.

# %%
# !ngrok config add-authtoken 2vompsZ2IA7jKGlK1qtZ9qkszcc_7PLsSzxGRbmzAjey6iYo6
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !ngrok config check
# Out:
# Valid configuration file at /root/.config/ngrok/ngrok.yml

# %%
# !ngrok config edit
# Out:
# Opening "/root/.config/ngrok/ngrok.yml" with `/bin/bash -c "nano \"/root/.config/ngrok/ngrok.yml\""`
# ERROR:  exit status 127

# %%
# !ngrok authtoken 2vompsZ2IA7jKGlK1qtZ9qkszcc_7PLsSzxGRbmzAjey6iYo6
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !huggingface-cli login
# !python main.py
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# The token `JUNKO` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# ...
